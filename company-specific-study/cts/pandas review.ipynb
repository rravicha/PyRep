# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d= {'Day':[1,2,3,4,5,6], "Visitors":[1000, 700,6000,1000,400,350], "Bounce_Rate":[20,20, 23,15,10,34]}
df= pd.DataFrame(d)
print(df)

# %%
df.set_index('Day',inplace=True)

# %%
df

# %%
df.describe()

# %%
df=pd.read_csv('data.csv')

# %%
df

# %%
df.describe()

# %%
df

# %%
df.max()

# %%
df.min()

# %%
df.columns

# %%
df['POP'].dtype

# %%
df[['country','year']]

# %%
df

# %%
df.set_index('country')

# %%
df[['country','year']][df.dog==df.dog.max]

# %%
df.set_index('country',inplace=True)

# %%
df

# %%
df.loc['India']

# %%
def alias(cell):
    if cell=='na':
        return("Unkown")
    elif cell=='IND':
        return('India')
    elif cell=='US':
        return("United States of America")
    else:
        return(cell)

# %%
df=pd.read_excel('data.xlsx',converters={'country':alias})

# %%
df

# %%
df.to_excel('data_formated.xlsx','Countries_GDP')

# %%
import sys
sys.version_info

# %%
df.to_html('Global-GDP.html')

# %%
df

# %%
dfn=df.fillna(0)

# %%
dfn

# %%
df=pd.read_excel('data.xlsx')

# %%
df

# %%
dfn=df.fillna('0')
dfn

# %%
df=pd.read_excel('data.xlsx')
df

# %%
dfn=df.fillna(method="ffill")
dfn

# %%
df={
    'name':'ragu','age':30,
    'name':'susi','age':2,
    'name':'loki','age':0
   }

# %%
df

# %%
#Chennai Weather Data Analysis

# %%
cwd=pd.read_excel('ChennaiWeatherData.xlsx','data')

# %%
cwd

# %%
fd=cwd.fillna(0)
fd

# %%
def line():
    print('_________________________________________________')

# %%
c=cwd.fillna(
    {
        'temperature':0.0,
        'windspeed':0,
        'event':"Feed Pending"
    }
)
c

# %%
c=cwd.fillna(method='ffill',limit=1)
line();print(cwd);line();print(c);line();
# Out:
# _________________________________________________
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0        NaN    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08          NaN        NaN    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy
# _________________________________________________
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0   Cloudy
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0       20.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# ...

# %%
c=cwd.fillna(method='bfill')
line();print(cwd);line();print(c);line();
# Out:
# _________________________________________________
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0        NaN    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08          NaN        NaN    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy
# _________________________________________________
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0    Sunny
# 3 2018-01-04         33.0       20.0    Sunny
# 4 2018-01-05         35.0       30.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# ...

# %%
c1=cwd.fillna(method='bfill',axis="rows")
c2=cwd.fillna(method='bfill',axis="rows",limit=2)
print(c1);line();print(c2);line();
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0    Sunny
# 3 2018-01-04         33.0       20.0    Sunny
# 4 2018-01-05         35.0       30.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0    Rainy
# 7 2018-01-08         25.0       45.0    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy
# _________________________________________________
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0    Sunny
# 3 2018-01-04         33.0       20.0    Sunny
# 4 2018-01-05         35.0       30.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0    Rainy
# ...

# %%
cwd
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0        NaN    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08          NaN        NaN    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy

# %%
c2
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0    Sunny
# 3 2018-01-04         33.0       20.0    Sunny
# 4 2018-01-05         35.0       30.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0    Rainy
# 7 2018-01-08         25.0       45.0    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy

# %%
cwd=pd.read_excel('ChennaiWeatherData.xlsx')

# %%
cwd

# %%
for i in range(10):
    c=cwd.fillna(method=input(),limit=int(input()),axis='columns')
    print(cwd)
    line()
    print(c)

# %%
cwd

# %%
cwd.interpolate()

# %%
cwd=pd.read_excel('ChennaiWeatherData.xlsx')

# %%
cwd
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0        NaN    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08          NaN        NaN    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy

# %%
cwd.interpolate()
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0       25.0    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08         31.0       40.0    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy

# %%
dir(cwd)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df.cumsum
# Out:
# <bound method DataFrame.cumsum of                     country country isocode  year          POP       XRAT  \
# 0                 Argentina             ARG  2000    37335.653   0.999500
# 1                 Australia             AUS  2000    19053.186   1.724830
# 2                     India             IND  2000  1006300.297  44.941600
# 3                    Israel             ISR  2000     6114.570   4.077330
# 4                    Unkown             MWI  2000    11801.505  59.543808
# 5              South Africa             ZAF  2000    45064.098   6.939830
# 6  United States of America             USA  2000   282171.957   1.000000
# 7                    Unkown            Test     0        0.000   0.000000
#
#           tcgdp         cc       cg
# 0  2.950722e+05  75.716805   5.5788
# 1  5.418047e+05  67.759026   6.7201
# 2  1.728144e+06  64.575551  14.0722
# 3  1.292539e+05  64.436451  10.2667
# 4  5.026222e+03  74.707624   11.659
# 5  2.272424e+05  72.718710  5.72655
# ...

# %%
df
# Out:
#                     country country isocode  year          POP       XRAT  \
# 0                 Argentina             ARG  2000    37335.653   0.999500
# 1                 Australia             AUS  2000    19053.186   1.724830
# 2                     India             IND  2000  1006300.297  44.941600
# 3                    Israel             ISR  2000     6114.570   4.077330
# 4                    Unkown             MWI  2000    11801.505  59.543808
# 5              South Africa             ZAF  2000    45064.098   6.939830
# 6  United States of America             USA  2000   282171.957   1.000000
# 7                    Unkown            Test     0        0.000   0.000000
#
#           tcgdp         cc       cg
# 0  2.950722e+05  75.716805   5.5788
# 1  5.418047e+05  67.759026   6.7201
# 2  1.728144e+06  64.575551  14.0722
# 3  1.292539e+05  64.436451  10.2667
# 4  5.026222e+03  74.707624   11.659
# 5  2.272424e+05  72.718710  5.72655
# 6  9.898700e+06  72.347054  6.03245
# ...

# %%
df=pd.read_excel('ChennaiWeatherData.xlsx')

# %%
df
# Out:
#         day   temperature  windspeed     event
# 0 2018-01-01         32.0          5    Cloudy
# 1 2018-01-02         28.5         10    Cloudy
# 2 2018-01-03         31.0         15  No Event
# 3 2018-01-04         33.0         20  No Event
# 4 2018-01-05         35.0        999     Sunny
# 5 2018-01-06         36.0         30   Drizzle
# 6 2018-01-07         37.0         35  No Event
# 7 2018-01-08         99.0        999     Rainy
# 8 2018-01-09         25.0         45     Rainy
# 9 2018-01-10         21.0         50    Cloudy

# %%
import numpy as np

# %%
df1=df.replace({
    'temperature':99,
    'windspeed':999,
    'event':'No Event'
    
},np.NaN)

# %%
df1
# Out:
#         day   temperature  windspeed    event
# 0 2018-01-01         32.0        5.0   Cloudy
# 1 2018-01-02         28.5       10.0   Cloudy
# 2 2018-01-03         31.0       15.0      NaN
# 3 2018-01-04         33.0       20.0      NaN
# 4 2018-01-05         35.0        NaN    Sunny
# 5 2018-01-06         36.0       30.0  Drizzle
# 6 2018-01-07         37.0       35.0      NaN
# 7 2018-01-08          NaN        NaN    Rainy
# 8 2018-01-09         25.0       45.0    Rainy
# 9 2018-01-10         21.0       50.0   Cloudy

# %%
df
# Out:
#         day   temperature  windspeed     event
# 0 2018-01-01         32.0          5    Cloudy
# 1 2018-01-02         28.5         10    Cloudy
# 2 2018-01-03         31.0         15  No Event
# 3 2018-01-04         33.0         20  No Event
# 4 2018-01-05         35.0        999     Sunny
# 5 2018-01-06         36.0         30   Drizzle
# 6 2018-01-07         37.0         35  No Event
# 7 2018-01-08         99.0        999     Rainy
# 8 2018-01-09         25.0         45     Rainy
# 9 2018-01-10         21.0         50    Cloudy

# %%
df1=df.replace
({
    999:0.0
})
# Out:
# {999: 0.0}

# %%
df1
# Out:
# <bound method DataFrame.replace of         day   temperature  windspeed     event
# 0 2018-01-01         32.0          5    Cloudy
# 1 2018-01-02         28.5         10    Cloudy
# 2 2018-01-03         31.0         15  No Event
# 3 2018-01-04         33.0         20  No Event
# 4 2018-01-05         35.0        999     Sunny
# 5 2018-01-06         36.0         30   Drizzle
# 6 2018-01-07         37.0         35  No Event
# 7 2018-01-08         99.0        999     Rainy
# 8 2018-01-09         25.0         45     Rainy
# 9 2018-01-10         21.0         50    Cloudy>

# %%
cwd=pd.read_excel('ChennaiWeatherData.xlsx','data')

# %%
cwd
# Out:
#         day  temperature windspeed     event
# 0 2018-01-01        32 F     5 mph    Cloudy
# 1 2018-01-02        28.5        10    Cloudy
# 2 2018-01-03          31        15  No Event
# 3 2018-01-04          33        20  No Event
# 4 2018-01-05          35       999     Sunny
# 5 2018-01-06          36        30   Drizzle
# 6 2018-01-07          37        35  No Event
# 7 2018-01-08          99       999     Rainy
# 8 2018-01-09          25        45     Rainy
# 9 2018-01-10        21 C    50 mph    Cloudy

# %%
cwdf=cwd.replace({
 'temperature':'[A-Za-z]',   
    'windspeed':'[A-Za-z]',
},'#',regex=True)
cwdf
# Out:
#         day  temperature windspeed     event
# 0 2018-01-01        32 #     5 ###    Cloudy
# 1 2018-01-02        28.5        10    Cloudy
# 2 2018-01-03          31        15  No Event
# 3 2018-01-04          33        20  No Event
# 4 2018-01-05          35       999     Sunny
# 5 2018-01-06          36        30   Drizzle
# 6 2018-01-07          37        35  No Event
# 7 2018-01-08          99       999     Rainy
# 8 2018-01-09          25        45     Rainy
# 9 2018-01-10        21 #    50 ###    Cloudy

# %%
grade={
    'student':['rick','tom','dick','harry','John'],
    'score':[0,100,30,50,0]
}

# %%
grade
# Out:
# {'student': ['rick', 'tom', 'dick', 'harry', 'John'],
#  'score': [0, 100, 30, 50, 0]}

# %%
grade_df=pd.DataFrame(grade)

# %%
grade_df
# Out:
#   student  score
# 0    rick      0
# 1     tom    100
# 2    dick     30
# 3   harry     50
# 4    John      0

# %%
grade_df.replace([100,30,50,0],['good','bad','average','absent'])
# Out:
#   student    score
# 0    rick   absent
# 1     tom     good
# 2    dick      bad
# 3   harry  average
# 4    John   absent

# %%
grade_df.replace({'student':'rick'},'Bot')
# Out:
#   student  score
# 0     Bot      0
# 1     tom    100
# 2    dick     30
# 3   harry     50
# 4    John      0

# %%
cwd=pd.read_excel('ChennaiWeatherData.xlsx')

# %%
cwd
# Out:
#         day         city temperature windspeed     event
# 0 2018-01-01     chennai        32 F     5 mph    Cloudy
# 1 2018-01-02     chennai        28.5        10    Cloudy
# 2 2018-01-03     chennai          31        15  No Event
# 3 2018-01-04     chennai          33        20  No Event
# 4 2018-01-05  coimbatore          35       999     Sunny
# 5 2018-01-06  coimbatore          36        30   Drizzle
# 6 2018-01-07  coimbatore          37        35  No Event
# 7 2018-01-08       salem          99       999     Rainy
# 8 2018-01-09       salem          25        45     Rainy
# 9 2018-01-10       salem        21 C    50 mph    Cloudy

# %%
g=cwd.groupby('city')

# %%
g

# %%
for city,frame in g:
    print(city)
    line()
    print(frame)
    print('\n')
# Out:
# chennai
# _________________________________________________
#         day      city temperature windspeed     event
# 0 2018-01-01  chennai        32 F     5 mph    Cloudy
# 1 2018-01-02  chennai        28.5        10    Cloudy
# 2 2018-01-03  chennai          31        15  No Event
# 3 2018-01-04  chennai          33        20  No Event
#
#
# coimbatore
# _________________________________________________
#         day         city temperature windspeed     event
# 4 2018-01-05  coimbatore          35       999     Sunny
# 5 2018-01-06  coimbatore          36        30   Drizzle
# 6 2018-01-07  coimbatore          37        35  No Event
#
#
# salem
# _________________________________________________
#         day    city temperature windspeed   event
# 7 2018-01-08  salem          99       999   Rainy
# 8 2018-01-09  salem          25        45   Rainy
# 9 2018-01-10  salem        21 C    50 mph  Cloudy

# %%
g.get_group('chennai')
# Out:
#         day      city temperature windspeed     event
# 0 2018-01-01  chennai        32 F     5 mph    Cloudy
# 1 2018-01-02  chennai        28.5        10    Cloudy
# 2 2018-01-03  chennai          31        15  No Event
# 3 2018-01-04  chennai          33        20  No Event

# %%
g.max()
# Out:
#                  day      event
# city
# chennai    2018-01-04  No Event
# coimbatore 2018-01-07     Sunny
# salem      2018-01-10     Rainy

# %%
g=cwd.groupby(['city','temperature'])

# %%
g

# %%
for x,y in g:
    print(x)
# Out:
# ('chennai', 28.5)
# ('chennai', 31)
# ('chennai', 33)
# ('chennai', '32 F')
# ('coimbatore', 35)
# ('coimbatore', 36)
# ('coimbatore', 37)
# ('salem', 25)
# ('salem', 99)
# ('salem', '21 C')

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-119-c79523bc0c66> in <module>
# ----> 1 g.mean()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#      71         return self._wrap_agged_blocks(new_items, new_blocks)
#      72
#
# ...

# %%
g.describe()
# Out:
#                         day                                    \
#                        count unique                  top freq
# city       temperature
# chennai    28.5            1      1  2018-01-02 00:00:00    1
#            31              1      1  2018-01-03 00:00:00    1
#            33              1      1  2018-01-04 00:00:00    1
#            32 F            1      1  2018-01-01 00:00:00    1
# coimbatore 35              1      1  2018-01-05 00:00:00    1
#            36              1      1  2018-01-06 00:00:00    1
#            37              1      1  2018-01-07 00:00:00    1
# salem      25              1      1  2018-01-09 00:00:00    1
#            99              1      1  2018-01-08 00:00:00    1
#            21 C            1      1  2018-01-10 00:00:00    1
#
#                                                                  windspeed  \
#                                       first                 last     count
# city       temperature
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g.plot()
# Out:
# /home/susi/.local/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   ax.set_xlim(left, right)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ...

# %%
c=pd.read_excel('ChennaiWeatherData.xlsx')

# %%
c
# Out:
#         day         city  temperature  windspeed     event
# 0 2018-01-01     chennai         32.0          5    Cloudy
# 1 2018-01-02     chennai         28.5         10    Cloudy
# 2 2018-01-03     chennai         31.0         15  No Event
# 3 2018-01-04     chennai         33.0         20  No Event
# 4 2018-01-05  coimbatore         35.0         25     Sunny
# 5 2018-01-06  coimbatore         36.0         30   Drizzle
# 6 2018-01-07  coimbatore         37.0         35  No Event
# 7 2018-01-08       salem         99.0         30     Rainy
# 8 2018-01-09       salem         25.0         45     Rainy
# 9 2018-01-10       salem         21.0         50    Cloudy

# %%
city=c.groupby('city')

# %%
city

# %%
city.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~/.local/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
s=pd.read_csv('/home/susi/Downloads/statement.csv')

# %%
s1=s[['Date','Balance']]
#s

# %%
type(s1)
# Out:
# pandas.core.frame.DataFrame

# %%
s2=s1.groupby('Date')

# %%
for d,b in s2:
    print(d)
    line()
    print(b)
# Out:
# 01-Jun-2019
# _________________________________________________
#           Date   Balance
# 0  01-Jun-2019  49595.62
# 03-Jul-2019
# _________________________________________________
#            Date  Balance
# 22  03-Jul-2019  20619.5
# 04-Jul-2019
# _________________________________________________
#            Date  Balance
# 23  04-Jul-2019  18509.5
# 24  04-Jul-2019  18051.5
# 05-Aug-2019
# _________________________________________________
#            Date  Balance
# 32  05-Aug-2019   5554.7
# 08-Jul-2019
# _________________________________________________
#            Date  Balance
# 25  08-Jul-2019  25551.5
# 10-Jun-2019
# _________________________________________________
#           Date   Balance
# 1  10-Jun-2019  44595.62
# 2  10-Jun-2019  34595.62
# 3  10-Jun-2019  24595.62
# 12-Jun-2019
# _________________________________________________
#           Date   Balance
# 4  12-Jun-2019  54595.62
# 5  12-Jun-2019  59595.62
# 6  12-Jun-2019  62095.62
# ...

# %%
s1.plot()

# %%
import seaborn as sns

# %%
bal=pd.read_csv('/home/susi/Downloads/statement.csv')

# %%
#Concatenating Data Sets

# %%
iw1=pd.read_excel('ChennaiWeatherData.xlsx','india')
iw2=pd.read_excel('ChennaiWeatherData.xlsx','us')

# %%
iw1
# Out:
#         city  hum  temp
# 0    chennai    5    45
# 1  bangalore   10    30
# 2     mumbai   15    32

# %%
iw2
# Out:
#          city  hum  temp
# 0  california   65    35
# 1    new york   87    45
# 2     orlando   54    36

# %%
pd.concat([iw1,iw2])
# Out:
#          city  hum  temp
# 0     chennai    5    45
# 1   bangalore   10    30
# 2      mumbai   15    32
# 0  california   65    35
# 1    new york   87    45
# 2     orlando   54    36

# %%
pd.concat([iw1,iw2],ignore_index=True3)
# Out:
#          city  hum  temp
# 0     chennai    5    45
# 1   bangalore   10    30
# 2      mumbai   15    32
# 3  california   65    35
# 4    new york   87    45
# 5     orlando   54    36

# %%
pd.concat([iw1,iw2],keys=["i","u"])
# Out:
#            city  hum  temp
# i 0     chennai    5    45
#   1   bangalore   10    30
#   2      mumbai   15    32
# u 0  california   65    35
#   1    new york   87    45
#   2     orlando   54    36

# %%
df.loc('i')
# Out:
# -------------------------------------------------------
# ValueError            Traceback (most recent call last)
# <ipython-input-184-790c08f6302e> in <module>
# ----> 1 df.loc('i')
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     100
#     101         if axis is not None:
# --> 102             axis = self.obj._get_axis_number(axis)
#     103         new_self.axis = axis
#     104         return new_self
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named i for object type <class 'type'>
